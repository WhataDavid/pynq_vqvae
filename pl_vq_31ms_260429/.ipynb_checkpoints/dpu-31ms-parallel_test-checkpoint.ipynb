# %%
import os
import sys
import time
import threading
import queue
import numpy as np
import struct
import cv2
from pynq import allocate

# --- 1. 环境初始化 ---
WORK_DIR = '/home/xilinx/jupyter_notebooks/duxu/pynq_vqvae'
sys.path.append('/usr/lib/python3/site-packages')
sys.path.insert(0, '/home/xilinx/jupyter_notebooks/soft/DPU-PYNQ')

from pynq_dpu import DpuOverlay
import vart
import xir

# 加载硬件 (如果是重启后第一次运行，建议 Restart Kernel)
overlay = DpuOverlay(os.path.join(WORK_DIR, 'pl_vq_31ms_260429/dpu.bit'))
vq_ip = overlay.vq_accel_1

# 获取 Runner
def get_dpu_subgraph(path):
    graph = xir.Graph.deserialize(path)
    return graph, graph.get_root_subgraph().toposort_child_subgraph()[1]

enc_graph, enc_subgraph = get_dpu_subgraph(os.path.join(WORK_DIR, 'xmodel/encoder_zcu111_700x500_old.xmodel'))
enc_runner = vart.Runner.create_runner(enc_subgraph, "run")
dec_graph, dec_subgraph = get_dpu_subgraph(os.path.join(WORK_DIR, 'xmodel/decoder_zcu111_700x500_old.xmodel'))
dec_runner = vart.Runner.create_runner(dec_subgraph, "run")

# 参数
enc_out_scale = 0.015625 
dec_in_scale  = 0.03125  
dec_out_scale = 0.007812
num_vectors = 125 * 175
dim = 64

# 分配内存
vq_in_z = allocate(shape=(num_vectors, dim), dtype=np.int8, cacheable=0)
vq_in_cb = allocate(shape=(512, 64), dtype=np.float32, cacheable=0)
vq_out_zq = allocate(shape=(num_vectors, dim), dtype=np.int8, cacheable=0)

vq_in_cb[:] = np.load(os.path.join(WORK_DIR, 'codebook.npy')).astype(np.float32)
vq_in_cb.sync_to_device()

def write_float(offset, val):
    f_hex = struct.unpack('<I', struct.pack('<f', float(val)))[0]
    vq_ip.mmio.write(offset, f_hex)

# --- 流水线 ---
PRE_DIR = './imgs_preprocessed'
data_files = sorted([f for f in os.listdir(PRE_DIR) if f.endswith('.npy')])
num_imgs = len(data_files)
dpu_res_queue = queue.Queue(maxsize=2)

def dpu_worker():
    for f in data_files:
        input_data = np.load(os.path.join(PRE_DIR, f))
        in_buf = [np.ascontiguousarray(input_data[np.newaxis])]
        out_buf = [np.empty((1, 125, 175, 64), dtype=np.int8, order='C')]
        job_id = enc_runner.execute_async(in_buf, out_buf)
        enc_runner.wait(job_id)
        dpu_res_queue.put(out_buf[0].copy())
    dpu_res_queue.put(None)

def run_pipeline():
    t_dpu = threading.Thread(target=dpu_worker)
    t_dpu.start()

    all_zq_results = []
    start_time = time.time()

    # 预先获取固定地址
    cb_addr = int(vq_in_codebook.device_address)
    zq_addr = int(vq_out_zq.device_address)

    for count in range(num_imgs):
        # 1. 获取 DPU 结果
        dpu_data = dpu_res_queue.get()
        if dpu_data is None: break
        
        # 2. 检查 DPU 数据是否真的在变（调试用）
        # print(f"DEBUG: DPU Data Sum: {np.sum(dpu_data)}")

        # 3. 强制清空并填充 VQ 输入 Buffer
        vq_in_z[:] = dpu_data.reshape(num_vectors, dim)
        vq_in_z.sync_to_device() # 确保刷入 DDR
        z_in_addr = int(vq_in_z.device_address)

        # 4. [最关键] 每一帧都重新显式写入所有控制寄存器
        # 先确保 IP 处于 IDLE
        while not (vq_ip.read(0x00) & 0x4): # 检查 AP_IDLE 位
            pass

        # 重新注入地址
        vq_ip.mmio.write(0x10, z_in_addr & 0xFFFFFFFF)
        vq_ip.mmio.write(0x14, (z_in_addr >> 32) & 0xFFFFFFFF)
        
        vq_ip.mmio.write(0x1c, cb_addr & 0xFFFFFFFF)
        vq_ip.mmio.write(0x20, (cb_addr >> 32) & 0xFFFFFFFF)
        
        vq_ip.mmio.write(0x28, zq_addr & 0xFFFFFFFF)
        vq_ip.mmio.write(0x2c, (zq_addr >> 32) & 0xFFFFFFFF)

        # 重新注入 Scale 参数
        write_float(0x34, enc_out_scale)
        write_float(0x3c, 1.0 / dec_in_scale)

        # 5. 启动硬件
        vq_ip.write(0x00, 0x01) # AP_START
        
        # 6. 等待完成
        while not (vq_ip.read(0x00) & 0x2): # AP_DONE
            pass
            
        # 7. 同步结果并彻底拷贝
        vq_out_zq.sync_from_device()
        all_zq_results.append(np.array(vq_out_zq, copy=True)) # 强制深度拷贝
        
        print(f" [Frame {count}] OutMean: {np.mean(vq_out_zq):.4f} | Data[0:3]: {vq_out_zq[0, 0:3]}")

    t_dpu.join()
run_pipeline()
# Out:
#  [Frame 0] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 1] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 2] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 3] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 4] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 5] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 6] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 7] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 8] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
#  [Frame 9] OutMean: -1.3349 | Slice: [-3 -1  7 11 -7]
